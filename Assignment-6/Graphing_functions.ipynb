# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourav7490/ma22c046_2023_PL/blob/main/Assignment-6/Graphing_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.linspace(0,10,1000)
#calculate the value y
y = np.sin(x)

# %%
# Now plot the function.
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel("sin(x)")
plt.title('Graph of sin(x)')
plt.grid(True)
plt.show()

# %%
x = np.linspace(-5,5,80)
y = np.linspace(-5,5,80)
X, Y = np.meshgrid(x, y)
z = np.cos(np.sqrt(X**2+Y**2))

# %%
from mpl_toolkits import mplot3d
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, z, rstride=1, cstride=1,cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()
